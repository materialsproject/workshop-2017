# %% [markdown]
# - https://materialsproject.org/mpcontribs
# - https://jupyterhub.materialsproject.org -> "MPContribs" Button in upper right corner
# - `pmg config --add PMG_MAPI_KEY <USER_API_KEY>` [copy & paste on Windows!]
# - https://refractiveindex.info/
# - https://docs.google.com/spreadsheets/d/1mjsUpxyG4oXoyRll3iTR_dUw4sCS0bY-mweK8kP_Hog
#
# ### Ingester
#
# ### Contribution Details & Custom Landing Pages
#
# ### Embedding in Materials Details Page
#
# to be deployed and integrated with production. Show prototype in MPContribs Explorer for now.
#
# ### Interact with Data through Rester

# %%
from mpcontribs.users.mp_workshop_2017.rest.rester import MpWorkshop2017Rester

# %%
mpr = MpWorkshop2017Rester(test_site=True)

# %%
mpr.preamble
# Out:
# u'https://jupyterhub.materialsproject.org/flaskproxy/tschaume/test_site/mpcontribs/rest'

# %%
mpr.query_contributions()
# Out:
# [{u'_id': u'5984cb36043b4b280043439a',
#   u'collaborators': [u'Patrick Huck'],
#   u'mp_cat_id': u'mp-1021328',
#   u'project': u'LBNL'},
#  {u'_id': u'5984cb3b043b4b280043439c',
#   u'collaborators': [u'Patrick Huck'],
#   u'mp_cat_id': u'mp-987',
#   u'project': u'LBNL'}]

# %%
mpfile = mpr.find_contribution('5984cb36043b4b280043439a')
mpid = mpfile.ids[0]

# %%
mpfile.hdata[mpid]['data']
# Out:
# <div id='27680692-f8a1-4c2e-b49c-939e12f9c73b' style='width:100%;'></div><script>
#     require(["json.human"], function(JsonHuman) {
#       "use strict";
#       var data = JSON.parse('{"extinction_coefficient": "nan", "refractive_index": "1.0004365", "chromatic_dispersion": "-3.0769e-06"}');
#       var node = JsonHuman.format(data);
#       document.getElementById('27680692-f8a1-4c2e-b49c-939e12f9c73b').appendChild(node);
#     });
#     </script>

# %%
mpfile.gdata[mpid]
# Out:
# <h3>refractive_index</h3>
# <div id="363a4785-c6f5-4a52-8417-de80d8c2b806" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("363a4785-c6f5-4a52-8417-de80d8c2b806", [{"y": [1.00044, 1.00044, 1.00043, 1.00043, 1.00043, 1.00043, 1.00045, 1.00044, 1.00044, 1.00044, 1.00044, 1.00044, 1.00044, 1.00044, 1.00043, 1.00043, 1.00043, 1.00043, 1.00043, 1.00043, 1.00042, 1.00042, 1.00041, 1.00047, 1.0004600000000001, 1.0004600000000001, 1.0004600000000001, 1.0004600000000001, 1.0004600000000001, 1.0004600000000001, 1.00045, 1.00045, 1.00045, 1.00045, 1.00045, 1.00045, 1.00045, 1.00045, 1.00045, 1.00045, 1.00045, 1.00045, 1.00045, 1.00045, 1.00045, 1.00045, 1.00044, 1.00045, 1.00044], "x": [1.68, 1.94, 2.67, 2.79, 2.96, 3.0, 3.64, 3.75, 3.9, 4.04, 4.45,